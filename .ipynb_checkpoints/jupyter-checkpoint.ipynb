# %%
from os import listdir
from os.path import isfile, join
import sklearn 
from sklearn.datasets import load_files

from sklearn.feature_extraction.text import TfidfVectorizer

cat = ['business','entertainment']
#do not load filecontents
datas =load_files('datasets/bbc/' ,categories=cat ,load_content=True ,shuffle=True, encoding='utf8', decode_error = 'strict' , random_state=0)                 

tfidf = TfidfVectorizer(encoding='utf8', decode_error='strict', tokenizer=None, analyzer='word', stop_words=None ,ngram_range=(1, 1), max_df=1.0, min_df=1, max_features=None, vocabulary=None,binary=False, norm='l2', use_idf= True, smooth_idf=True,sublinear_tf=False )
X = tfidf.fit_transform(datas.data)

print(X)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
import os

def ensure_dir(file_path):
    directory = os.path.dirname(file_path)
    if not os.path.exists(directory):
        os.makedirs(directory)
        
if not os.path.exists("directory"):
    os.makedirs("directory")

# %% [markdown]
# #

# %%
from __future__ import print_function
from collections import defaultdict
import sklearn.datasets
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.cluster import MiniBatchKMeans
import numpy as np
from sklearn.cluster import Birch
import sklearn

categories = [
   "business" ,"sport" , 'entertainment', 'tech','politics']
print("Loading 20 newsgroups dataset for categories:")
#print(categories)

dataset = sklearn.datasets.load_files('/home/mabrin/project/cluster/datasets/bbcTest/',
                                      description=None, categories=categories ,
                                      load_content=True, shuffle=True, encoding = 'utf-8',decode_error='ignore',
                                      random_state=25)


print("%d documents" % len(dataset.data))
print("%d categories" % len(dataset.target_names))
print("*******************")
#print(dataset.target)
true_k = 5
print(dataset.filenames)
vectorizer = TfidfVectorizer(max_df=.3, max_features=175 ,
                                 min_df=10
                             , stop_words='english',
                                 use_idf=True)
#print(type(dataset.data))


Y = vectorizer.fit_transform(dataset.data[125:])

cur = Y.toarray()

print( np.size(cur[1]))

X = vectorizer.fit_transform(dataset.data[:125])

km = MiniBatchKMeans(n_clusters=true_k, init='k-means++', n_init=1,init_size=1000, batch_size=1000)
km.fit(X)



    


clusters = defaultdict(list)

k = 0;
for i in km.labels_ :
  clusters[i].append(dataset.filenames[k])  
  k += 1
  
'''for clust in clusters :
  print ("\n************************\n")
  for filename in clusters[clust] :
    print (filename)'''
print("*****************************************************")

#print(np.size(km.cluster_centers_[j]),">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
#print(Y.shape , ">>>>                  >>>>>>>>>>>>>>>>")

print(np.shape(km.cluster_centers_[1].reshape(1,-1)))
print,np.shape(cur[1]).reshape(1,-1))

#left_doc , tmp = Y.shape

for i in range(0,left_doc):
    clust = []
    for j in range (5):
        x = km.cluster_centers_[j]
        y = cur[i]
        clust.append(sklearn.metrics.pairwise.euclidean_distances(x.reshape(1,-1) , y.reshape(1,-1),
                        Y_norm_squared=None, squared=False, X_norm_squared=None))
    print(np.argmin(clust))
    print(i)

order_centroids = km.cluster_centers_.argsort()[:, ::-1]

terms = vectorizer.get_feature_names()
'''for i in range(true_k):
        print("Cluster %d:" % i, end='')
        for ind in order_centroids[i, :200]:
            print(' %s' % terms[ind], end='')
        print()'''
# Out:
# Loading 20 newsgroups dataset for categories:
# 1251 documents
# 5 categories
# *******************
# ['/home/mabrin/project/cluster/datasets/bbcTest/politics/107.txt'
#  '/home/mabrin/project/cluster/datasets/bbcTest/tech/055.txt'
#  '/home/mabrin/project/cluster/datasets/bbcTest/business/154.txt' ...,
#  '/home/mabrin/project/cluster/datasets/bbcTest/entertainment/225.txt'
#  '/home/mabrin/project/cluster/datasets/bbcTest/entertainment/069.txt'
#  '/home/mabrin/project/cluster/datasets/bbcTest/tech/156.txt']
# 175
# *****************************************************
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-e0eca003a251> in <module>()
#      66 #print(Y.shape , ">>>>                  >>>>>>>>>>>>>>>>")
#      67
# ---> 68 print(np.shape(km.cluster_centers_[1].reshape(1,-1)),np.shape(cur[1]).reshape(1,-1))
#      69
#      70 #left_doc , tmp = Y.shape
#
# AttributeError: 'tuple' object has no attribute 'reshape'

# %%
from collections import defaultdict
import sklearn.datasets
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.cluster import MiniBatchKMeans
import numpy as np
import sklearn

categories = [
   'business','entertainment',"sport" , 'tech','politics']

dataset = sklearn.datasets.load_files('/home/mabrin/project/cluster/datasets/bbcTest/',
                                      description=None, categories=categories ,
                                      load_content=True, shuffle=False, 
                                      encoding = 'utf-8',decode_error='ignore',
                                      random_state= 70)

datasetT = sklearn.datasets.load_files('/home/mabrin/project/cluster/datasets/bbc/',
                                      description=None, categories=categories ,
                                      load_content=True, shuffle=True, 
                                      encoding = 'utf-8',decode_error='ignore',
                                      random_state= 42)


true_k = 5 #no of groups

vectorizer = TfidfVectorizer(max_df=.6, max_features=250 ,min_df=.01 ,
                                    stop_words='english',use_idf=True)
                                    
X2 = vectorizer.fit_transform(dataset.data[:50]).toarray()
X5 = vectorizer.fit_transform(dataset.data[50:100]).toarray()
X3 = vectorizer.fit_transform(dataset.data[100:150]).toarray()
X4 = vectorizer.fit_transform(dataset.data[150:200]).toarray()
X1 = vectorizer.fit_transform(dataset.data[200:]).toarray()
X6 = vectorizer.fit_transform(datasetT.data).toarray()

X = [X1,X2,X3,X4,X5]


centriole=[]
for i in X:
    print(i.shape)
    s = []
    for k in range(i.shape[1]):
        
        tmp =float(0)
        for l in range(i.shape[0]):
            tmp = tmp+ i[l,k]
        s.append(tmp / 50)
    centriole.append(s)
exit

'''for i in X:
    km = MiniBatchKMeans(n_clusters=1, init='k-means++', n_init=1,
                    init_size=1000,batch_size=1000)
    km.fit(X1)
    centriole.append(km.cluster_centers_[0])
'''

    

cur = X6

clusters = [[],[],[],[],[]]

for i in range(5):
    for filename in dataset.filenames[i*50:(i+1)*50-1]:
        clusters[i].append(filename)

exit

x = centriole[0]
y = cur[0]

   

#centers = km.cluster_centers_
for i in range(0,len(X6)):
    clust = []
    for j in range (true_k):
        x = np.array(centriole[j])
        y = cur[i]
        #print(len(x),type(x))
        #print(len(y),type(y))
        #clust.append(sklearn.metrics.pairwise.euclidean_distances(x.reshape(1,-1),
                # y.reshape(1,-1), Y_norm_squared=None, squared=False, X_norm_squared=None))
        clust.append(((np.dot(x,x) + np.dot(y,y) - 2* np.dot(x,y))**0.5)*1.0)
    k =np.argmin(clust)
    centriole[k] = centriole[k] + y/float(len(clusters[k]))
    clusters[k].append(datasetT.filenames[i])
print(len(clusters))
for i in range(true_k):
        for j in clusters[i]:
                print(j)    
        print()



#outfile = "out.txt"
#np.savetxt(outfile,(np.hstack((dataset.filenames[125:],tmp))) ,delimiter = ',')
# Out:
# (50, 250)
# (50, 250)
# (50, 250)
# (50, 250)
# (50, 250)
# 5
# /home/mabrin/project/cluster/datasets/bbcTest/business/001.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/002.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/003.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/004.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/005.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/006.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/007.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/008.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/009.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/010.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/011.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/012.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/013.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/014.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/015.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/016.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/017.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/018.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/019.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/020.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/021.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/022.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/023.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/024.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/025.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/026.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/027.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/028.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/029.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/030.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/031.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/032.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/033.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/034.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/035.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/036.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/037.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/038.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/039.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/040.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/041.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/042.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/043.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/044.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/045.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/046.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/047.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/048.txt
# /home/mabrin/project/cluster/datasets/bbcTest/business/049.txt
# /home/mabrin/project/cluster/datasets/bbc/business/415.txt
# /home/mabrin/project/cluster/datasets/bbc/business/417.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/337.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/046.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/168.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/005.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/295.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/374.txt
# /home/mabrin/project/cluster/datasets/bbc/business/351.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/121.txt
# /home/mabrin/project/cluster/datasets/bbc/business/427.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/287.txt
# /home/mabrin/project/cluster/datasets/bbc/business/481.txt
# /home/mabrin/project/cluster/datasets/bbc/business/030.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/078.txt
# /home/mabrin/project/cluster/datasets/bbc/business/112.txt
# /home/mabrin/project/cluster/datasets/bbc/business/248.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/026.txt
# /home/mabrin/project/cluster/datasets/bbc/business/361.txt
# /home/mabrin/project/cluster/datasets/bbc/business/362.txt
# /home/mabrin/project/cluster/datasets/bbc/business/110.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/008.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/271.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/091.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/298.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/037.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/309.txt
# /home/mabrin/project/cluster/datasets/bbc/business/439.txt
# /home/mabrin/project/cluster/datasets/bbc/business/180.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/278.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/010.txt
# /home/mabrin/project/cluster/datasets/bbc/business/071.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/333.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/142.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/127.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/029.txt
# /home/mabrin/project/cluster/datasets/bbc/business/325.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/303.txt
# /home/mabrin/project/cluster/datasets/bbc/business/479.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/032.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/128.txt
# /home/mabrin/project/cluster/datasets/bbc/business/410.txt
# /home/mabrin/project/cluster/datasets/bbc/business/045.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/352.txt
# /home/mabrin/project/cluster/datasets/bbc/business/185.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/217.txt
# /home/mabrin/project/cluster/datasets/bbc/business/026.txt
# /home/mabrin/project/cluster/datasets/bbc/business/255.txt
# /home/mabrin/project/cluster/datasets/bbc/business/322.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/210.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/283.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/158.txt
# /home/mabrin/project/cluster/datasets/bbc/business/049.txt
# /home/mabrin/project/cluster/datasets/bbc/business/121.txt
# /home/mabrin/project/cluster/datasets/bbc/business/290.txt
# /home/mabrin/project/cluster/datasets/bbc/business/057.txt
# /home/mabrin/project/cluster/datasets/bbc/business/283.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/045.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/112.txt
# /home/mabrin/project/cluster/datasets/bbc/business/496.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/206.txt
# /home/mabrin/project/cluster/datasets/bbc/business/355.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/109.txt
# /home/mabrin/project/cluster/datasets/bbc/business/240.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/360.txt
# /home/mabrin/project/cluster/datasets/bbc/business/495.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/335.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/388.txt
# /home/mabrin/project/cluster/datasets/bbc/business/125.txt
# /home/mabrin/project/cluster/datasets/bbc/business/066.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/229.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/123.txt
# /home/mabrin/project/cluster/datasets/bbc/business/213.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/389.txt
# /home/mabrin/project/cluster/datasets/bbc/business/409.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/297.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/161.txt
# /home/mabrin/project/cluster/datasets/bbc/business/221.txt
# /home/mabrin/project/cluster/datasets/bbc/business/297.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/356.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/226.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/278.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/084.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/321.txt
# /home/mabrin/project/cluster/datasets/bbc/business/436.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/240.txt
# /home/mabrin/project/cluster/datasets/bbc/business/317.txt
# /home/mabrin/project/cluster/datasets/bbc/business/122.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/330.txt
# /home/mabrin/project/cluster/datasets/bbc/business/077.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/222.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/250.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/256.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/105.txt
# /home/mabrin/project/cluster/datasets/bbc/business/434.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/243.txt
# /home/mabrin/project/cluster/datasets/bbc/business/472.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/054.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/185.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/159.txt
# /home/mabrin/project/cluster/datasets/bbc/business/480.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/178.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/017.txt
# /home/mabrin/project/cluster/datasets/bbc/business/024.txt
# /home/mabrin/project/cluster/datasets/bbc/business/428.txt
# /home/mabrin/project/cluster/datasets/bbc/business/050.txt
# /home/mabrin/project/cluster/datasets/bbc/business/174.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/275.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/059.txt
# /home/mabrin/project/cluster/datasets/bbc/business/072.txt
# /home/mabrin/project/cluster/datasets/bbc/business/163.txt
# /home/mabrin/project/cluster/datasets/bbc/business/257.txt
# /home/mabrin/project/cluster/datasets/bbc/business/441.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/377.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/138.txt
# /home/mabrin/project/cluster/datasets/bbc/business/464.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/262.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/246.txt
# /home/mabrin/project/cluster/datasets/bbc/business/084.txt
# /home/mabrin/project/cluster/datasets/bbc/business/462.txt
# /home/mabrin/project/cluster/datasets/bbc/business/175.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/237.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/218.txt
# /home/mabrin/project/cluster/datasets/bbc/business/430.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/346.txt
# /home/mabrin/project/cluster/datasets/bbc/business/459.txt
# /home/mabrin/project/cluster/datasets/bbc/business/079.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/130.txt
# /home/mabrin/project/cluster/datasets/bbc/business/306.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/328.txt
# /home/mabrin/project/cluster/datasets/bbc/business/484.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/064.txt
# /home/mabrin/project/cluster/datasets/bbc/business/046.txt
# /home/mabrin/project/cluster/datasets/bbc/business/295.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/033.txt
# /home/mabrin/project/cluster/datasets/bbc/business/437.txt
# /home/mabrin/project/cluster/datasets/bbc/business/031.txt
# /home/mabrin/project/cluster/datasets/bbc/business/345.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/253.txt
# /home/mabrin/project/cluster/datasets/bbc/business/301.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/030.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/263.txt
# /home/mabrin/project/cluster/datasets/bbc/business/040.txt
# /home/mabrin/project/cluster/datasets/bbc/business/463.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/140.txt
# /home/mabrin/project/cluster/datasets/bbc/business/195.txt
# /home/mabrin/project/cluster/datasets/bbc/business/323.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/251.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/347.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/184.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/171.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/215.txt
# /home/mabrin/project/cluster/datasets/bbc/business/344.txt
# /home/mabrin/project/cluster/datasets/bbc/business/399.txt
# /home/mabrin/project/cluster/datasets/bbc/business/142.txt
# /home/mabrin/project/cluster/datasets/bbc/business/340.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/098.txt
# /home/mabrin/project/cluster/datasets/bbc/business/440.txt
# /home/mabrin/project/cluster/datasets/bbc/business/272.txt
# /home/mabrin/project/cluster/datasets/bbc/business/416.txt
# /home/mabrin/project/cluster/datasets/bbc/business/311.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/103.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/289.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/208.txt
# /home/mabrin/project/cluster/datasets/bbc/business/183.txt
# /home/mabrin/project/cluster/datasets/bbc/business/171.txt
# /home/mabrin/project/cluster/datasets/bbc/business/159.txt
# /home/mabrin/project/cluster/datasets/bbc/business/273.txt
# /home/mabrin/project/cluster/datasets/bbc/business/372.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/092.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/332.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/131.txt
# /home/mabrin/project/cluster/datasets/bbc/business/137.txt
# /home/mabrin/project/cluster/datasets/bbc/business/016.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/220.txt
# /home/mabrin/project/cluster/datasets/bbc/business/466.txt
# /home/mabrin/project/cluster/datasets/bbc/business/200.txt
# /home/mabrin/project/cluster/datasets/bbc/business/044.txt
# /home/mabrin/project/cluster/datasets/bbc/business/108.txt
# /home/mabrin/project/cluster/datasets/bbc/business/498.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/090.txt
# /home/mabrin/project/cluster/datasets/bbc/business/073.txt
# /home/mabrin/project/cluster/datasets/bbc/business/507.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/070.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/395.txt
# /home/mabrin/project/cluster/datasets/bbc/business/406.txt
# /home/mabrin/project/cluster/datasets/bbc/business/310.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/232.txt
# /home/mabrin/project/cluster/datasets/bbc/business/149.txt
# /home/mabrin/project/cluster/datasets/bbc/business/292.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/195.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/151.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/152.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/066.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/115.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/179.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/364.txt
# /home/mabrin/project/cluster/datasets/bbc/business/042.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/192.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/098.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/248.txt
# /home/mabrin/project/cluster/datasets/bbc/business/237.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/393.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/205.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/211.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/122.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/093.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/085.txt
# /home/mabrin/project/cluster/datasets/bbc/business/119.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/197.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/236.txt
# /home/mabrin/project/cluster/datasets/bbc/business/381.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/225.txt
# /home/mabrin/project/cluster/datasets/bbc/business/085.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/163.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/265.txt
# /home/mabrin/project/cluster/datasets/bbc/business/007.txt
# /home/mabrin/project/cluster/datasets/bbc/business/469.txt
# /home/mabrin/project/cluster/datasets/bbc/business/182.txt
# /home/mabrin/project/cluster/datasets/bbc/business/165.txt
# /home/mabrin/project/cluster/datasets/bbc/business/288.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/234.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/268.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/133.txt
# /home/mabrin/project/cluster/datasets/bbc/business/055.txt
# /home/mabrin/project/cluster/datasets/bbc/business/286.txt
# /home/mabrin/project/cluster/datasets/bbc/business/429.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/160.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/213.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/235.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/071.txt
# /home/mabrin/project/cluster/datasets/bbc/business/156.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/321.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/129.txt
# /home/mabrin/project/cluster/datasets/bbc/business/347.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/373.txt
# /home/mabrin/project/cluster/datasets/bbc/business/244.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/349.txt
# /home/mabrin/project/cluster/datasets/bbc/business/371.txt
# /home/mabrin/project/cluster/datasets/bbc/business/356.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/386.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/202.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/032.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/004.txt
# /home/mabrin/project/cluster/datasets/bbc/business/289.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/054.txt
# /home/mabrin/project/cluster/datasets/bbc/business/420.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/372.txt
# /home/mabrin/project/cluster/datasets/bbc/business/143.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/047.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/290.txt
# /home/mabrin/project/cluster/datasets/bbc/business/296.txt
# /home/mabrin/project/cluster/datasets/bbc/business/402.txt
# /home/mabrin/project/cluster/datasets/bbc/business/089.txt
# /home/mabrin/project/cluster/datasets/bbc/business/132.txt
# /home/mabrin/project/cluster/datasets/bbc/business/270.txt
# /home/mabrin/project/cluster/datasets/bbc/business/376.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/044.txt
# /home/mabrin/project/cluster/datasets/bbc/business/329.txt
# /home/mabrin/project/cluster/datasets/bbc/business/172.txt
# /home/mabrin/project/cluster/datasets/bbc/business/259.txt
# /home/mabrin/project/cluster/datasets/bbc/business/139.txt
# /home/mabrin/project/cluster/datasets/bbc/business/113.txt
# /home/mabrin/project/cluster/datasets/bbc/business/225.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/242.txt
# /home/mabrin/project/cluster/datasets/bbc/business/194.txt
# /home/mabrin/project/cluster/datasets/bbc/business/504.txt
# /home/mabrin/project/cluster/datasets/bbc/business/004.txt
# /home/mabrin/project/cluster/datasets/bbc/business/006.txt
# /home/mabrin/project/cluster/datasets/bbc/business/277.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/152.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/113.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/087.txt
# /home/mabrin/project/cluster/datasets/bbc/business/228.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/145.txt
# /home/mabrin/project/cluster/datasets/bbc/business/067.txt
# /home/mabrin/project/cluster/datasets/bbc/business/086.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/099.txt
# /home/mabrin/project/cluster/datasets/bbc/business/363.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/124.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/203.txt
# /home/mabrin/project/cluster/datasets/bbc/business/028.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/216.txt
# /home/mabrin/project/cluster/datasets/bbc/business/056.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/209.txt
# /home/mabrin/project/cluster/datasets/bbc/business/008.txt
# /home/mabrin/project/cluster/datasets/bbc/business/107.txt
# /home/mabrin/project/cluster/datasets/bbc/business/350.txt
# /home/mabrin/project/cluster/datasets/bbc/business/239.txt
# /home/mabrin/project/cluster/datasets/bbc/business/214.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/284.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/199.txt
# /home/mabrin/project/cluster/datasets/bbc/business/061.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/157.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/392.txt
# /home/mabrin/project/cluster/datasets/bbc/business/360.txt
# /home/mabrin/project/cluster/datasets/bbc/business/111.txt
# /home/mabrin/project/cluster/datasets/bbc/business/126.txt
# /home/mabrin/project/cluster/datasets/bbc/business/053.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/050.txt
# /home/mabrin/project/cluster/datasets/bbc/business/184.txt
# /home/mabrin/project/cluster/datasets/bbc/business/138.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/287.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/322.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/041.txt
# /home/mabrin/project/cluster/datasets/bbc/business/249.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/349.txt
# /home/mabrin/project/cluster/datasets/bbc/business/098.txt
# /home/mabrin/project/cluster/datasets/bbc/business/075.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/198.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/134.txt
# /home/mabrin/project/cluster/datasets/bbc/business/236.txt
# /home/mabrin/project/cluster/datasets/bbc/business/268.txt
# /home/mabrin/project/cluster/datasets/bbc/business/118.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/164.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/296.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/327.txt
# /home/mabrin/project/cluster/datasets/bbc/business/001.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/212.txt
# /home/mabrin/project/cluster/datasets/bbc/business/405.txt
# /home/mabrin/project/cluster/datasets/bbc/business/385.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/179.txt
# /home/mabrin/project/cluster/datasets/bbc/business/063.txt
# /home/mabrin/project/cluster/datasets/bbc/business/146.txt
# /home/mabrin/project/cluster/datasets/bbc/business/374.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/371.txt
# /home/mabrin/project/cluster/datasets/bbc/business/450.txt
# /home/mabrin/project/cluster/datasets/bbc/business/256.txt
# /home/mabrin/project/cluster/datasets/bbc/business/390.txt
# /home/mabrin/project/cluster/datasets/bbc/business/461.txt
# /home/mabrin/project/cluster/datasets/bbc/business/502.txt
# /home/mabrin/project/cluster/datasets/bbc/business/041.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/021.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/338.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/162.txt
# /home/mabrin/project/cluster/datasets/bbc/business/134.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/219.txt
# /home/mabrin/project/cluster/datasets/bbc/business/505.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/375.txt
# /home/mabrin/project/cluster/datasets/bbc/business/387.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/143.txt
# /home/mabrin/project/cluster/datasets/bbc/business/173.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/204.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/310.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/344.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/173.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/167.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/322.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/289.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/285.txt
# /home/mabrin/project/cluster/datasets/bbc/business/170.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/174.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/358.txt
# /home/mabrin/project/cluster/datasets/bbc/business/492.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/058.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/148.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/150.txt
# /home/mabrin/project/cluster/datasets/bbc/business/109.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/052.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/291.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/361.txt
# /home/mabrin/project/cluster/datasets/bbc/business/455.txt
# /home/mabrin/project/cluster/datasets/bbc/business/076.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/184.txt
# /home/mabrin/project/cluster/datasets/bbc/business/396.txt
# /home/mabrin/project/cluster/datasets/bbc/business/177.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/005.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/298.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/229.txt
# /home/mabrin/project/cluster/datasets/bbc/business/413.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/107.txt
# /home/mabrin/project/cluster/datasets/bbc/business/115.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/359.txt
# /home/mabrin/project/cluster/datasets/bbc/business/012.txt
# /home/mabrin/project/cluster/datasets/bbc/business/285.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/256.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/148.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/325.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/342.txt
# /home/mabrin/project/cluster/datasets/bbc/business/258.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/263.txt
# /home/mabrin/project/cluster/datasets/bbc/business/442.txt
# /home/mabrin/project/cluster/datasets/bbc/business/023.txt
# /home/mabrin/project/cluster/datasets/bbc/business/357.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/216.txt
# /home/mabrin/project/cluster/datasets/bbc/business/474.txt
# /home/mabrin/project/cluster/datasets/bbc/business/218.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/016.txt
# /home/mabrin/project/cluster/datasets/bbc/business/094.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/214.txt
# /home/mabrin/project/cluster/datasets/bbc/business/247.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/317.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/193.txt
# /home/mabrin/project/cluster/datasets/bbc/business/488.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/246.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/124.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/281.txt
# /home/mabrin/project/cluster/datasets/bbc/business/117.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/231.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/228.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/321.txt
# /home/mabrin/project/cluster/datasets/bbc/business/120.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/182.txt
# /home/mabrin/project/cluster/datasets/bbc/business/370.txt
# /home/mabrin/project/cluster/datasets/bbc/business/047.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/247.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/103.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/376.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/063.txt
# /home/mabrin/project/cluster/datasets/bbc/business/471.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/076.txt
# /home/mabrin/project/cluster/datasets/bbc/business/020.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/175.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/025.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/281.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/318.txt
# /home/mabrin/project/cluster/datasets/bbc/business/408.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/025.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/018.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/011.txt
# /home/mabrin/project/cluster/datasets/bbc/business/490.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/069.txt
# /home/mabrin/project/cluster/datasets/bbc/business/018.txt
# /home/mabrin/project/cluster/datasets/bbc/business/128.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/384.txt
# /home/mabrin/project/cluster/datasets/bbc/business/253.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/183.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/211.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/274.txt
# /home/mabrin/project/cluster/datasets/bbc/business/477.txt
# /home/mabrin/project/cluster/datasets/bbc/business/158.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/386.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/141.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/341.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/142.txt
# /home/mabrin/project/cluster/datasets/bbc/business/226.txt
# /home/mabrin/project/cluster/datasets/bbc/business/438.txt
# /home/mabrin/project/cluster/datasets/bbc/business/038.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/240.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/059.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/383.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/130.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/155.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/181.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/280.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/061.txt
# /home/mabrin/project/cluster/datasets/bbc/business/153.txt
# /home/mabrin/project/cluster/datasets/bbc/business/099.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/279.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/240.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/168.txt
# /home/mabrin/project/cluster/datasets/bbc/business/054.txt
# /home/mabrin/project/cluster/datasets/bbc/business/152.txt
# /home/mabrin/project/cluster/datasets/bbc/business/009.txt
# /home/mabrin/project/cluster/datasets/bbc/business/453.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/015.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/254.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/343.txt
# /home/mabrin/project/cluster/datasets/bbc/business/144.txt
# /home/mabrin/project/cluster/datasets/bbc/business/151.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/146.txt
# /home/mabrin/project/cluster/datasets/bbc/business/473.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/153.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/131.txt
# /home/mabrin/project/cluster/datasets/bbc/business/147.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/163.txt
# /home/mabrin/project/cluster/datasets/bbc/business/187.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/107.txt
# /home/mabrin/project/cluster/datasets/bbc/business/294.txt
# /home/mabrin/project/cluster/datasets/bbc/business/002.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/300.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/241.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/175.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/215.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/363.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/164.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/031.txt
# /home/mabrin/project/cluster/datasets/bbc/business/207.txt
# /home/mabrin/project/cluster/datasets/bbc/business/398.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/317.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/072.txt
# /home/mabrin/project/cluster/datasets/bbc/business/503.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/040.txt
# /home/mabrin/project/cluster/datasets/bbc/business/201.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/265.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/386.txt
# /home/mabrin/project/cluster/datasets/bbc/business/065.txt
# /home/mabrin/project/cluster/datasets/bbc/business/493.txt
# /home/mabrin/project/cluster/datasets/bbc/business/380.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/121.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/158.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/193.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/266.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/238.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/137.txt
# /home/mabrin/project/cluster/datasets/bbc/business/190.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/080.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/224.txt
# /home/mabrin/project/cluster/datasets/bbc/business/022.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/312.txt
# /home/mabrin/project/cluster/datasets/bbc/business/467.txt
#
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/001.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/002.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/003.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/004.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/005.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/006.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/007.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/008.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/009.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/010.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/011.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/012.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/013.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/014.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/015.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/016.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/017.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/018.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/019.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/020.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/021.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/022.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/023.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/024.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/025.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/026.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/027.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/028.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/029.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/030.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/031.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/032.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/033.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/034.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/035.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/036.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/037.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/038.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/039.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/040.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/041.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/042.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/043.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/044.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/045.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/046.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/047.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/048.txt
# /home/mabrin/project/cluster/datasets/bbcTest/entertainment/049.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/232.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/436.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/120.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/134.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/508.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/043.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/104.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/486.txt
# /home/mabrin/project/cluster/datasets/bbc/business/424.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/444.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/379.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/198.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/110.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/093.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/177.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/018.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/233.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/306.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/240.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/434.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/262.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/451.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/495.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/194.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/092.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/069.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/179.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/009.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/019.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/067.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/047.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/288.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/111.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/378.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/095.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/102.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/390.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/074.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/141.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/190.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/497.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/310.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/093.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/189.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/109.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/107.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/054.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/123.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/056.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/125.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/063.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/425.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/169.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/306.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/137.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/104.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/359.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/231.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/472.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/478.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/279.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/448.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/485.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/287.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/430.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/176.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/245.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/157.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/340.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/125.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/443.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/138.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/157.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/305.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/079.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/175.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/281.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/100.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/355.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/469.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/220.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/181.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/368.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/493.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/289.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/459.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/171.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/272.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/170.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/219.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/360.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/325.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/358.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/205.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/316.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/123.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/405.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/111.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/354.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/002.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/266.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/058.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/452.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/396.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/232.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/178.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/024.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/365.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/247.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/274.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/241.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/243.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/139.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/357.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/264.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/415.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/244.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/070.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/400.txt
# /home/mabrin/project/cluster/datasets/bbc/business/271.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/328.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/450.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/391.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/344.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/247.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/261.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/030.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/449.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/397.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/402.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/424.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/025.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/050.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/182.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/296.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/025.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/385.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/135.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/335.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/481.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/294.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/362.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/420.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/090.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/399.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/279.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/282.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/305.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/394.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/327.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/426.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/364.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/233.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/071.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/298.txt
# /home/mabrin/project/cluster/datasets/bbc/business/377.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/440.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/190.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/295.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/266.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/423.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/284.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/353.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/159.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/416.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/226.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/235.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/294.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/144.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/356.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/094.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/499.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/145.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/110.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/389.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/269.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/369.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/052.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/379.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/401.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/293.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/248.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/321.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/268.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/246.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/237.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/299.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/022.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/249.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/033.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/148.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/311.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/154.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/020.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/361.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/278.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/413.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/297.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/066.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/234.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/311.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/193.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/464.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/441.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/021.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/265.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/314.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/239.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/387.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/191.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/301.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/197.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/165.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/075.txt
# ...
# /home/mabrin/project/cluster/datasets/bbc/politics/176.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/020.txt
# /home/mabrin/project/cluster/datasets/bbc/business/082.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/078.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/207.txt
# /home/mabrin/project/cluster/datasets/bbc/business/330.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/048.txt
# /home/mabrin/project/cluster/datasets/bbc/business/088.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/035.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/176.txt
# /home/mabrin/project/cluster/datasets/bbc/business/349.txt
# /home/mabrin/project/cluster/datasets/bbc/business/178.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/208.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/042.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/350.txt
# /home/mabrin/project/cluster/datasets/bbc/business/458.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/012.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/067.txt
# /home/mabrin/project/cluster/datasets/bbc/business/032.txt
# /home/mabrin/project/cluster/datasets/bbc/business/215.txt
# /home/mabrin/project/cluster/datasets/bbc/business/327.txt
# /home/mabrin/project/cluster/datasets/bbc/business/342.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/133.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/380.txt
# /home/mabrin/project/cluster/datasets/bbc/business/386.txt
# /home/mabrin/project/cluster/datasets/bbc/business/313.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/118.txt
# /home/mabrin/project/cluster/datasets/bbc/business/127.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/082.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/214.txt
# /home/mabrin/project/cluster/datasets/bbc/business/011.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/117.txt
# /home/mabrin/project/cluster/datasets/bbc/business/130.txt
# /home/mabrin/project/cluster/datasets/bbc/business/324.txt
# /home/mabrin/project/cluster/datasets/bbc/business/015.txt
# /home/mabrin/project/cluster/datasets/bbc/business/478.txt
# /home/mabrin/project/cluster/datasets/bbc/business/391.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/236.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/309.txt
# /home/mabrin/project/cluster/datasets/bbc/business/422.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/367.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/019.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/252.txt
# /home/mabrin/project/cluster/datasets/bbc/business/334.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/268.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/015.txt
# /home/mabrin/project/cluster/datasets/bbc/business/013.txt
# /home/mabrin/project/cluster/datasets/bbc/business/261.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/246.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/006.txt
# /home/mabrin/project/cluster/datasets/bbc/business/140.txt
# /home/mabrin/project/cluster/datasets/bbc/business/326.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/259.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/051.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/091.txt
# /home/mabrin/project/cluster/datasets/bbc/business/468.txt
# /home/mabrin/project/cluster/datasets/bbc/business/243.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/003.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/303.txt
# /home/mabrin/project/cluster/datasets/bbc/business/315.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/290.txt
# /home/mabrin/project/cluster/datasets/bbc/business/425.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/381.txt
# /home/mabrin/project/cluster/datasets/bbc/business/025.txt
# /home/mabrin/project/cluster/datasets/bbc/business/145.txt
# /home/mabrin/project/cluster/datasets/bbc/business/485.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/304.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/131.txt
# /home/mabrin/project/cluster/datasets/bbc/business/365.txt
# /home/mabrin/project/cluster/datasets/bbc/business/078.txt
# /home/mabrin/project/cluster/datasets/bbc/business/303.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/115.txt
# /home/mabrin/project/cluster/datasets/bbc/business/337.txt
# /home/mabrin/project/cluster/datasets/bbc/business/048.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/045.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/091.txt
# /home/mabrin/project/cluster/datasets/bbc/business/233.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/001.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/002.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/179.txt
# /home/mabrin/project/cluster/datasets/bbc/business/093.txt
# /home/mabrin/project/cluster/datasets/bbc/business/281.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/051.txt
# /home/mabrin/project/cluster/datasets/bbc/business/043.txt
# /home/mabrin/project/cluster/datasets/bbc/business/205.txt
# /home/mabrin/project/cluster/datasets/bbc/business/069.txt
# /home/mabrin/project/cluster/datasets/bbc/business/133.txt
# /home/mabrin/project/cluster/datasets/bbc/business/081.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/105.txt
# /home/mabrin/project/cluster/datasets/bbc/business/166.txt
# /home/mabrin/project/cluster/datasets/bbc/business/447.txt
# /home/mabrin/project/cluster/datasets/bbc/business/103.txt
# /home/mabrin/project/cluster/datasets/bbc/business/435.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/023.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/366.txt
# /home/mabrin/project/cluster/datasets/bbc/business/389.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/118.txt
# /home/mabrin/project/cluster/datasets/bbc/business/250.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/398.txt
# /home/mabrin/project/cluster/datasets/bbc/business/095.txt
# /home/mabrin/project/cluster/datasets/bbc/business/034.txt
# /home/mabrin/project/cluster/datasets/bbc/business/449.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/014.txt
# /home/mabrin/project/cluster/datasets/bbc/business/083.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/089.txt
# /home/mabrin/project/cluster/datasets/bbc/business/105.txt
# /home/mabrin/project/cluster/datasets/bbc/business/224.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/310.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/370.txt
# /home/mabrin/project/cluster/datasets/bbc/business/010.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/029.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/271.txt
# /home/mabrin/project/cluster/datasets/bbc/business/373.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/158.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/023.txt
# /home/mabrin/project/cluster/datasets/bbc/business/358.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/022.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/273.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/227.txt
# /home/mabrin/project/cluster/datasets/bbc/business/080.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/260.txt
# /home/mabrin/project/cluster/datasets/bbc/business/058.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/038.txt
# /home/mabrin/project/cluster/datasets/bbc/business/348.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/129.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/319.txt
# /home/mabrin/project/cluster/datasets/bbc/business/476.txt
# /home/mabrin/project/cluster/datasets/bbc/business/039.txt
# /home/mabrin/project/cluster/datasets/bbc/business/091.txt
# /home/mabrin/project/cluster/datasets/bbc/business/167.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/206.txt
# /home/mabrin/project/cluster/datasets/bbc/business/500.txt
# /home/mabrin/project/cluster/datasets/bbc/business/339.txt
# /home/mabrin/project/cluster/datasets/bbc/business/029.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/137.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/394.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/039.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/170.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/044.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/279.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/200.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/034.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/225.txt
# /home/mabrin/project/cluster/datasets/bbc/business/265.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/255.txt
# /home/mabrin/project/cluster/datasets/bbc/business/062.txt
# /home/mabrin/project/cluster/datasets/bbc/business/279.txt
# /home/mabrin/project/cluster/datasets/bbc/business/037.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/010.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/079.txt
# /home/mabrin/project/cluster/datasets/bbc/business/192.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/299.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/203.txt
# /home/mabrin/project/cluster/datasets/bbc/business/418.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/355.txt
# /home/mabrin/project/cluster/datasets/bbc/business/090.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/016.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/358.txt
# /home/mabrin/project/cluster/datasets/bbc/business/499.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/381.txt
# /home/mabrin/project/cluster/datasets/bbc/business/397.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/257.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/337.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/180.txt
# /home/mabrin/project/cluster/datasets/bbc/business/160.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/128.txt
# /home/mabrin/project/cluster/datasets/bbc/business/336.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/339.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/036.txt
# /home/mabrin/project/cluster/datasets/bbc/business/341.txt
# /home/mabrin/project/cluster/datasets/bbc/business/432.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/101.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/204.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/224.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/048.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/123.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/354.txt
# /home/mabrin/project/cluster/datasets/bbc/business/269.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/040.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/324.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/231.txt
# /home/mabrin/project/cluster/datasets/bbc/business/005.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/286.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/108.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/196.txt
# /home/mabrin/project/cluster/datasets/bbc/business/264.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/077.txt
# /home/mabrin/project/cluster/datasets/bbc/business/444.txt
# /home/mabrin/project/cluster/datasets/bbc/business/305.txt
# /home/mabrin/project/cluster/datasets/bbc/business/314.txt
# /home/mabrin/project/cluster/datasets/bbc/business/150.txt
# /home/mabrin/project/cluster/datasets/bbc/business/051.txt
# /home/mabrin/project/cluster/datasets/bbc/business/400.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/117.txt
# /home/mabrin/project/cluster/datasets/bbc/business/321.txt
# /home/mabrin/project/cluster/datasets/bbc/business/036.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/353.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/167.txt
# /home/mabrin/project/cluster/datasets/bbc/business/155.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/066.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/032.txt
# /home/mabrin/project/cluster/datasets/bbc/business/191.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/244.txt
# /home/mabrin/project/cluster/datasets/bbc/business/181.txt
# /home/mabrin/project/cluster/datasets/bbc/business/302.txt
# /home/mabrin/project/cluster/datasets/bbc/business/280.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/159.txt
# /home/mabrin/project/cluster/datasets/bbc/business/017.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/177.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/029.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/189.txt
# /home/mabrin/project/cluster/datasets/bbc/business/284.txt
# /home/mabrin/project/cluster/datasets/bbc/business/027.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/374.txt
# /home/mabrin/project/cluster/datasets/bbc/business/230.txt
# /home/mabrin/project/cluster/datasets/bbc/business/470.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/083.txt
# /home/mabrin/project/cluster/datasets/bbc/entertainment/178.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/334.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/116.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/308.txt
# /home/mabrin/project/cluster/datasets/bbc/business/161.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/291.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/096.txt
# /home/mabrin/project/cluster/datasets/bbc/business/510.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/191.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/052.txt
# /home/mabrin/project/cluster/datasets/bbc/business/104.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/120.txt
# /home/mabrin/project/cluster/datasets/bbc/business/404.txt
# /home/mabrin/project/cluster/datasets/bbc/business/208.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/119.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/292.txt
# /home/mabrin/project/cluster/datasets/bbc/business/254.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/001.txt
# /home/mabrin/project/cluster/datasets/bbc/business/346.txt
# /home/mabrin/project/cluster/datasets/bbc/business/263.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/190.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/188.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/342.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/282.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/136.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/033.txt
# /home/mabrin/project/cluster/datasets/bbc/business/489.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/020.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/301.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/357.txt
# /home/mabrin/project/cluster/datasets/bbc/business/198.txt
# /home/mabrin/project/cluster/datasets/bbc/business/401.txt
# /home/mabrin/project/cluster/datasets/bbc/business/123.txt
# /home/mabrin/project/cluster/datasets/bbc/business/203.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/340.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/030.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/329.txt
# /home/mabrin/project/cluster/datasets/bbc/business/318.txt
# /home/mabrin/project/cluster/datasets/bbc/sport/088.txt
# /home/mabrin/project/cluster/datasets/bbc/business/096.txt
# /home/mabrin/project/cluster/datasets/bbc/business/393.txt
# /home/mabrin/project/cluster/datasets/bbc/business/379.txt
# /home/mabrin/project/cluster/datasets/bbc/business/419.txt
# /home/mabrin/project/cluster/datasets/bbc/business/392.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/204.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/239.txt
# /home/mabrin/project/cluster/datasets/bbc/business/338.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/380.txt
# /home/mabrin/project/cluster/datasets/bbc/business/456.txt
# /home/mabrin/project/cluster/datasets/bbc/business/202.txt
# /home/mabrin/project/cluster/datasets/bbc/business/162.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/132.txt
# /home/mabrin/project/cluster/datasets/bbc/business/035.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/316.txt
# /home/mabrin/project/cluster/datasets/bbc/politics/187.txt
# /home/mabrin/project/cluster/datasets/bbc/business/475.txt
# /home/mabrin/project/cluster/datasets/bbc/business/460.txt
# /home/mabrin/project/cluster/datasets/bbc/business/131.txt
# /home/mabrin/project/cluster/datasets/bbc/business/331.txt
# /home/mabrin/project/cluster/datasets/bbc/tech/346.txt
